# %% [markdown]
# # R-C system

# %% [markdown]
# Charging of capacitor phenomena was used as second testing environment.
#
#
# It can be described be the relation:
#
# $$
# C \frac{dU_c}{dt} = \frac{U_s - U_c}{R}
# $$
